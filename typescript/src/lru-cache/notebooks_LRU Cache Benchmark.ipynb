# %%
import matplotlib.pyplot as plt

# %%
# using doubly-linked list for storing items order
as_dl_list_data = {
  'updating existing item in the cache': {
    '1000': 2.329288697651175,
    '2000': 2.2680828169696983,
    '3000': 2.3210825222388807,
    '4000': 2.6406531271708684,
    '5000': 2.661968517146331,
    '6000': 2.8935408969191276,
    '7000': 2.9212310115818005,
    '8000': 3.0172865461270866,
    '9000': 2.689267783389196,
    '10000': 2.80932044917189,
    '11000': 2.723514499133128,
    '12000': 2.8614331543966625,
    '13000': 2.883240167186696,
    '14000': 2.7801574534543723,
    '15000': 2.9143736817042614
  },
  'put a new item in the cache (evict the oldest item)': {
    '1000': 2.747247281873167,
    '2000': 3.026202962394623,
    '3000': 3.918918235294118,
    '4000': 3.8692052671568637,
    '5000': 3.7908737856063657,
    '6000': 4.566937957390108,
    '7000': 4.195441953061225,
    '8000': 3.9878529639101514,
    '9000': 3.7027445953159037,
    '10000': 2.2323973342911883,
    '11000': 2.212678025549725,
    '12000': 2.2367336838627447,
    '13000': 2.1756220739700374,
    '14000': 2.1862293757058833,
    '15000': 2.1659197622093025
  }
}

# %%
cache_sizes = [int(size) for size in as_dl_list_data['updating existing item in the cache'].keys()]
update_times = list(as_dl_list_data['updating existing item in the cache'].values())
evict_times = list(as_dl_list_data['put a new item in the cache (evict the oldest item)'].values())

plt.figure(figsize=(15, 5))
plt.xticks(range(1000, 16000, 1000))
plt.plot(cache_sizes, update_times, label='updating existing item in the cache')
plt.plot(cache_sizes, evict_times, label='put a new item in the cache (evict the oldest item)')

plt.xlabel('Cache Size')
plt.ylabel('Time (ms)')
plt.title('"Doubly-Linked" Cache')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.grid()
plt.show()

# %%
# using Array for for storing items order
as_array_data = {
  'updating existing item in the cache': {
    '1000': 56.14213548484848,
    '2000': 98.23137248275863,
    '3000': 139.79015463636364,
    '4000': 214.7174808125,
    '5000': 247.8953424,
    '6000': 317.83524866666664,
    '7000': 325.68800575,
    '8000': 385.61135836363644,
    '9000': 450.51652889999997,
    '10000': 525.39384,
    '11000': 534.679749111111,
    '12000': 870.6958518571428,
    '13000': 1076.3060967142858,
    '14000': 1266.4191371666666,
    '15000': 1470.5548161666666
  },
  'put a new item in the cache (evict the oldest item)': {
    '1000': 3.7076124556962022,
    '2000': 4.030796822431506,
    '3000': 4.384020151859101,
    '4000': 4.068493084760273,
    '5000': 3.9041564185654014,
    '6000': 4.068570963636362,
    '7000': 3.753785253012048,
    '8000': 3.9305558554421767,
    '9000': 4.056770184523809,
    '10000': 577.5574793333333,
    '11000': 630.913109375,
    '12000': 770.000360875,
    '13000': 729.9453745,
    '14000': 1832.2308773333332,
    '15000': 1561.470595
  }
}

# %%
cache_sizes = [int(size) for size in as_array_data['updating existing item in the cache'].keys()]
update_times = list(as_array_data['updating existing item in the cache'].values())
evict_times = list(as_array_data['put a new item in the cache (evict the oldest item)'].values())

plt.figure(figsize=(15, 10))
plt.xticks(range(1000, 16000, 1000))
plt.yticks(range(0, 1900, 50))

plt.plot(cache_sizes, update_times, label='updating existing item in the cache')
plt.plot(cache_sizes, evict_times, label='put a new item in the cache (evict the oldest item)')

plt.xlabel('Cache Size')
plt.ylabel('Time (ms)')
plt.title('"Naive" Cache (using Array)')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.grid()
plt.show()
